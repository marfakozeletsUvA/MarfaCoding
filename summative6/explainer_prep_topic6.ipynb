# %% [markdown]
# **ADDITION 1: WEIGHT THE PROBABILITY**

# %% [markdown]
# if state[node] == NORMAL:
#     for neighbor in G.neighbors(node):
#         if state[neighbor] >= INFLUENCED:
#             weight = G[node][neighbor]['weight']
#             adjusted_p = min(p_normal_to_influenced * weight / max_weight, 1.0)
#             if np.random.random() < adjusted_p:
#                 new_state[node] = INFLUENCED
#                 break
